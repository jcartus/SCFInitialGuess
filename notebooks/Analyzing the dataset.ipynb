# %%
import numpy as np
import matplotlib.pyplot as plt

from SCFInitialGuess.utilities.dataset import assemble_batch
from SCFInitialGuess.utilities.constants import number_of_basis_functions as N_BASIS

source = "../dataset"
species = "C"

# %%
x, y = assemble_batch(source, species)
# Out:
# [+] 2018-02-23 14:12:22: Assembling batch for: C
# [-] 2018-02-23 14:12:22: Fetching data from ../dataset
# [w] 2018-02-23 14:12:22: There was a problem: [Errno 2] No such file or directory: '../dataset/PyQChem/PyQChem.out'
# [w] 2018-02-23 14:12:22: There was a problem: [Errno 2] No such file or directory: '../dataset/PyQChem/s22/s22.out'
# [ ] 2018-02-23 14:12:22: No atoms of type C found in Ammonia-dimer_mono1
# [ ] 2018-02-23 14:12:22: No atoms of type C found in Ammonia-dimer
# [ ] 2018-02-23 14:12:23: No atoms of type C found in Benzene-water-complex_mono1
# [ ] 2018-02-23 14:12:23: No atoms of type C found in Ammonia-dimer_mono2
# [ ] 2018-02-23 14:12:24: No atoms of type C found in Water-dimer_mono2
# [ ] 2018-02-23 14:12:24: No atoms of type C found in Water-dimer_mono1
# [ ] 2018-02-23 14:12:25: No atoms of type C found in Water-dimer
# [ ] 2018-02-23 14:12:25: No atoms of type C found in Benzene-ammonia-complex_mono1
# ...

# %%
print(np.var(y, 0) / np.var(x, 0))
print("---------------------------------------")
print(np.min( x, 0))
print(np.max( x,0)) 
print(np.mean(x,0))
print("---------------------------------------")
print(np.min( y, 0))
print(np.max( y,0)) 
print(np.mean(y,0))
# Out:
# [  1.49884443e-07   8.89988188e-07   1.99310725e-05   1.60255803e-05
#    2.24826810e-05   8.08610872e-06   6.93638569e-06   6.46258451e-06
#    9.19886452e-06   7.76737480e-06   7.87261158e-06   6.86009765e-06
#    4.44521776e-06   1.01988707e-02   1.34305639e-03   1.61931012e-03
#    2.00833048e-04   2.42042472e-07   2.21899866e-07   1.77613199e-07
#    1.87879563e-07   1.73262239e-07]
# ---------------------------------------
# [ -0.25085723  -0.31369309  -4.23595424  -4.12100975  -4.4653713
#   -0.89937086  -9.06780194  -8.00281452  -8.35575716  -0.18699577
#  -23.75323734 -23.15773269 -22.45045552   0.         -49.70802243
#  -48.9078357  -51.34649446  -9.56675095 -10.15502439  -7.80365271
#   -9.43292119 -11.34154141]
# [   4.08244255    4.82138801    3.48522791    3.44265017    3.48950064
#    28.68066244   11.97817293   11.34828201   11.24174352   62.08264408
#    27.49662562   28.44371404   26.68910032  120.8077103    52.13785375
# ...

# %%
print(np.max( x,0) - np.min( x,0))
print("---------------------------------------")
print(np.max( y,0) - np.min( y,0))
# Out:
# [   4.33329979    5.1350811     7.72118215    7.56365992    7.95487194
#    29.5800333    21.04597487   19.35109654   19.59750068   62.26963985
#    51.24986296   51.60144673   49.13955584  120.8077103   101.84587617
#   112.92175595  113.2008367    18.32099111   19.34841577   18.47881276
#    18.15606631   20.9732052 ]
# ---------------------------------------
# [  5.36557459e-03   1.58372451e-02   4.93654192e-02   7.88272524e-02
#    5.84706483e-02   1.87666406e-01   1.14718110e-01   1.99485246e-01
#    1.44432891e-01   5.13472680e-01   4.99967805e-01   6.19344715e-01
#    1.87358613e-01   2.45928448e+01   1.54106251e+01   1.83366744e+01
#    4.06566359e+00   9.14942145e-03   9.11170139e-03   7.06999136e-03
#    8.18464251e-03   8.63601111e-03]

# %%
for input_index in range(N_BASIS[species]):
    fig = plt.figure()
    plt.scatter(x[:, input_index], y[:, input_index])
plt.show()
# Out:
# /home/jcartus/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
