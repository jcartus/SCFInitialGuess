# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import seaborn as sns

from os.path import join

plt.style.use(["seaborn", "thesis"])
# Out:
# /home/jo/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
plt.rc("figure", figsize=(8,4))

# %% [markdown]
# # Fetch Dataset

# %%
from SCFInitialGuess.utilities.dataset import extract_triu_batch, AbstractDataset
from sklearn.model_selection import train_test_split

data_path = "../../../dataset/TSmall_sto3g/"
postfix = "TSmall_sto3g"
dim = 26
#data_path = "../butadien/data/"
#postfix = ""
#dim = 26


def split(x, y, ind):
    return x[:ind], y[:ind], x[ind:], y[ind:]

S = np.load(join(data_path, "S" + postfix + ".npy"))
P = np.load(join(data_path, "P" + postfix + ".npy"))
F = np.load(join(data_path, "F" + postfix + ".npy"))

molecules = np.load(join(data_path, "molecules" + postfix + ".npy"))



ind = int(0.8 * len(molecules))
molecules_train, molecules_test = (molecules[:ind], molecules[ind:])

s_triu = extract_triu_batch(S, dim)
p_triu = extract_triu_batch(P, dim)

s_train, p_train, s_test, p_test = split(s_triu, p_triu, ind)

# %%
model_path = "../../../models"

# %% [markdown]
# #  Calculate Descriptors

# %%
from SCFInitialGuess.descriptors.high_level import \
    AtomicNumberWeighted
from SCFInitialGuess.descriptors.coordinate_descriptors import \
    Gaussians, SPHAngularDescriptor
from SCFInitialGuess.descriptors.cutoffs import \
    BehlerCutoff1
from SCFInitialGuess.descriptors.models import \
    RADIAL_GAUSSIAN_MODELS, make_uniform
import pickle    

    
descriptor = AtomicNumberWeighted(
    #Gaussians(*make_uniform(40, 80, 20)),
    Gaussians(*RADIAL_GAUSSIAN_MODELS["Man"]),
    SPHAngularDescriptor(4),
    BehlerCutoff1(5)
)

pickle.dump(descriptor, open(model_path + "descriptor.dump", "wb"))

print(descriptor.number_of_descriptors)
# Out:
# 100

# %%
descriptor.calculate_all_descriptors(molecules[0]).shape
# Out:
# (10, 100)

# %%
G = []
for mol in molecules:
    G.append(
        descriptor.calculate_all_descriptors(mol).flatten()
    )
    
G = np.asarray(G)

# %%
g_train, g_test = G[:ind], G[ind:]

# %%
G.shape
# Out:
# (1001, 1000)

# %% [markdown]
# # Setup Networks

# %%
dim_in = G.shape[1]
dim_triu = dim * (dim + 1) // 2

print(dim**2, dim_triu, dim_in)
# Out:
# 676 351 1000

# %%
keras.backend.clear_session()


activation = "elu"
learning_rate = 1e-5
intializer = keras.initializers.TruncatedNormal(mean=0.0, stddev=0.01)

model = keras.Sequential()

# input layer
model.add(keras.layers.Dense(700, activation=activation, input_dim=dim_in, kernel_initializer=intializer, bias_initializer='zeros'))

# hidden
#for i in range(3):

model.add(keras.layers.Dense(
    500, 
    activation=activation, 
    kernel_initializer=intializer, 
    #bias_initializer='zeros',
    #kernel_regularizer=keras.regularizers.l2(1e-8)
))


model.add(keras.layers.Dense(
        400, 
        activation=activation, 
        kernel_initializer=intializer, 
        #bias_initializer='zeros',
        #kernel_regularizer=keras.regularizers.l2(1e-8)
))


#output
model.add(keras.layers.Dense(dim_triu))

model.compile(optimizer=keras.optimizers.Adam(learning_rate), loss='MSE', metrics=['mae', 'mse'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 700)               700700
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               350500
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               200400
# _________________________________________________________________
# dense_3 (Dense)              (None, 351)               140751
# =================================================================
# Total params: 1,392,351
# Trainable params: 1,392,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
filepath = "../../../models/model_descriptos_" + postfix + ".h5"

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_mean_squared_error", 
    min_delta=1e-7, 
    patience=200, 
    verbose=1
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=50, 
    verbose=1, 
    mode='auto', 
    min_delta=1e-4, 
    cooldown=50, 
    min_lr=1e-10
)

checkpoint = keras.callbacks.ModelCheckpoint(
    filepath, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=False, 
    save_weights_only=False, 
    mode='auto', 
    period=1
)

# %%
i=0

# %%
i+=1
log_dir = "./log/Butadien_" + str(i)
tensorboard = keras.callbacks.TensorBoard(
    log_dir=log_dir, 
    histogram_freq=0, 
    batch_size=32, 
    #update_freq='epoch'
)

# %% [markdown]
# # Do the training

# %%
g_train.shape, p_train.shape
# Out:
# ((800, 1000), (800, 351))

# %%
epochs = 10000

while True:
    keras.backend.set_value(model.optimizer.lr, 1e-4)

    history = model.fit(
        x = g_train,
        y = p_train,
        epochs=epochs,
        shuffle=True,
        validation_data=(g_test, p_test), 
        verbose=1, 
        callbacks=[
            early_stopping, 
            reduce_lr, 
            checkpoint
        ]
    )
    
    print("\n\n\n\n\nNext rouuund!!")
# Out:
# Train on 800 samples, validate on 201 samples
# Epoch 1/10000
# 800/800 [==============================] - 0s 583us/step - loss: 0.0012 - mean_absolute_error: 0.0198 - mean_squared_error: 0.0012 - val_loss: 5.7059e-04 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 5.7059e-04
#
# Epoch 00001: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 2/10000
# 800/800 [==============================] - 0s 527us/step - loss: 2.6259e-04 - mean_absolute_error: 0.0117 - mean_squared_error: 2.6259e-04 - val_loss: 1.2807e-04 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.2807e-04
#
# Epoch 00002: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 3/10000
# 800/800 [==============================] - 0s 552us/step - loss: 7.1623e-05 - mean_absolute_error: 0.0062 - mean_squared_error: 7.1623e-05 - val_loss: 6.0133e-05 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.0133e-05
#
# Epoch 00003: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 4/10000
# 800/800 [==============================] - 0s 525us/step - loss: 3.7124e-05 - mean_absolute_error: 0.0045 - mean_squared_error: 3.7124e-05 - val_loss: 4.2774e-05 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 4.2774e-05
#
# Epoch 00004: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 5/10000
# 800/800 [==============================] - 0s 551us/step - loss: 2.3983e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 2.3983e-05 - val_loss: 3.5311e-05 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.5311e-05
#
# Epoch 00005: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 6/10000
# 800/800 [==============================] - 0s 529us/step - loss: 1.8665e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 1.8665e-05 - val_loss: 3.2900e-05 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.2900e-05
#
# Epoch 00006: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 7/10000
# 800/800 [==============================] - 0s 525us/step - loss: 1.7541e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 1.7541e-05 - val_loss: 3.2124e-05 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.2124e-05
#
# Epoch 00007: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 8/10000
# 800/800 [==============================] - 0s 520us/step - loss: 1.5118e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 1.5118e-05 - val_loss: 2.9895e-05 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.9895e-05
#
# Epoch 00008: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 9/10000
# 800/800 [==============================] - 0s 596us/step - loss: 1.4178e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 1.4178e-05 - val_loss: 2.8536e-05 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.8536e-05
#
# Epoch 00009: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 10/10000
# 800/800 [==============================] - 0s 562us/step - loss: 1.3259e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 1.3259e-05 - val_loss: 2.7557e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.7557e-05
#
# Epoch 00010: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 11/10000
# 800/800 [==============================] - 0s 482us/step - loss: 1.2741e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 1.2741e-05 - val_loss: 2.7752e-05 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.7752e-05
#
# Epoch 00011: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 12/10000
# 800/800 [==============================] - 0s 477us/step - loss: 1.2766e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 1.2766e-05 - val_loss: 2.7383e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.7383e-05
#
# Epoch 00012: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 13/10000
# 800/800 [==============================] - 0s 443us/step - loss: 1.2356e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 1.2356e-05 - val_loss: 2.6746e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.6746e-05
#
# Epoch 00013: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 14/10000
# 800/800 [==============================] - 0s 496us/step - loss: 1.2061e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 1.2061e-05 - val_loss: 2.6403e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.6403e-05
#
# Epoch 00014: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 15/10000
# 800/800 [==============================] - 0s 490us/step - loss: 1.1822e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1822e-05 - val_loss: 2.6172e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.6172e-05
#
# Epoch 00015: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 16/10000
# 800/800 [==============================] - 0s 524us/step - loss: 1.1764e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1764e-05 - val_loss: 2.6333e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.6333e-05
#
# Epoch 00016: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 17/10000
# 800/800 [==============================] - 0s 463us/step - loss: 1.1613e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1613e-05 - val_loss: 2.5673e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5673e-05
#
# Epoch 00017: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 18/10000
# 800/800 [==============================] - 0s 473us/step - loss: 1.1297e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1297e-05 - val_loss: 2.5606e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5606e-05
#
# Epoch 00018: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 19/10000
# 800/800 [==============================] - 0s 445us/step - loss: 1.0999e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.0999e-05 - val_loss: 2.5373e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5373e-05
#
# Epoch 00019: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 20/10000
# 800/800 [==============================] - 0s 408us/step - loss: 1.1171e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1171e-05 - val_loss: 2.5044e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5044e-05
#
# Epoch 00020: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 21/10000
# 800/800 [==============================] - 0s 458us/step - loss: 1.1093e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1093e-05 - val_loss: 2.5324e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5324e-05
#
# Epoch 00021: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 22/10000
# 800/800 [==============================] - 0s 427us/step - loss: 1.1056e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1056e-05 - val_loss: 2.4984e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.4984e-05
#
# Epoch 00022: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 23/10000
# 800/800 [==============================] - 0s 425us/step - loss: 1.0962e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.0962e-05 - val_loss: 2.4852e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.4852e-05
#
# Epoch 00023: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 24/10000
# 800/800 [==============================] - 0s 462us/step - loss: 1.0620e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0620e-05 - val_loss: 2.4469e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4469e-05
#
# Epoch 00024: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 25/10000
# 800/800 [==============================] - 0s 444us/step - loss: 1.0515e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0515e-05 - val_loss: 2.4447e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4447e-05
#
# Epoch 00025: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 26/10000
# 800/800 [==============================] - 0s 430us/step - loss: 1.0473e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0473e-05 - val_loss: 2.4198e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4198e-05
#
# Epoch 00026: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 27/10000
# 800/800 [==============================] - 0s 404us/step - loss: 1.0417e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0417e-05 - val_loss: 2.4209e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4209e-05
#
# Epoch 00027: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 28/10000
# 800/800 [==============================] - 0s 391us/step - loss: 1.0202e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0202e-05 - val_loss: 2.3925e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3925e-05
#
# Epoch 00028: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 29/10000
# 800/800 [==============================] - 0s 424us/step - loss: 1.0208e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0208e-05 - val_loss: 2.4060e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4060e-05
#
# Epoch 00029: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 30/10000
# 800/800 [==============================] - 0s 423us/step - loss: 1.0306e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0306e-05 - val_loss: 2.4157e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4157e-05
#
# Epoch 00030: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 31/10000
# 800/800 [==============================] - 0s 385us/step - loss: 1.0295e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0295e-05 - val_loss: 2.4041e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4041e-05
#
# Epoch 00031: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 32/10000
# 800/800 [==============================] - 0s 370us/step - loss: 1.0290e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0290e-05 - val_loss: 2.4205e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4205e-05
#
# Epoch 00032: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 33/10000
# 800/800 [==============================] - 0s 362us/step - loss: 1.0382e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0382e-05 - val_loss: 2.4293e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4293e-05
#
# Epoch 00033: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 34/10000
# 800/800 [==============================] - 0s 383us/step - loss: 1.0730e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0730e-05 - val_loss: 2.4877e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.4877e-05
#
# Epoch 00034: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 35/10000
# 800/800 [==============================] - 0s 394us/step - loss: 1.1149e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1149e-05 - val_loss: 2.4799e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.4799e-05
#
# Epoch 00035: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 36/10000
# 800/800 [==============================] - 0s 423us/step - loss: 1.1249e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1249e-05 - val_loss: 2.4236e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4236e-05
#
# Epoch 00036: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 37/10000
# 800/800 [==============================] - 0s 389us/step - loss: 1.0887e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0887e-05 - val_loss: 2.4442e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4442e-05
#
# Epoch 00037: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 38/10000
# 800/800 [==============================] - 0s 421us/step - loss: 1.0244e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0244e-05 - val_loss: 2.3370e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.3370e-05
#
# Epoch 00038: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 39/10000
# 800/800 [==============================] - 0s 405us/step - loss: 1.0278e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0278e-05 - val_loss: 2.2823e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.2823e-05
#
# Epoch 00039: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 40/10000
# 800/800 [==============================] - 0s 452us/step - loss: 1.0643e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0643e-05 - val_loss: 2.3919e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3919e-05
#
# Epoch 00040: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 41/10000
# 800/800 [==============================] - 0s 443us/step - loss: 1.1002e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1002e-05 - val_loss: 2.4482e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.4482e-05
#
# Epoch 00041: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 42/10000
# 800/800 [==============================] - 0s 435us/step - loss: 1.0574e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0574e-05 - val_loss: 2.4407e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4407e-05
#
# Epoch 00042: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 43/10000
# 800/800 [==============================] - 0s 412us/step - loss: 1.0318e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0318e-05 - val_loss: 2.3324e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3324e-05
#
# Epoch 00043: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 44/10000
# 800/800 [==============================] - 0s 466us/step - loss: 1.0516e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0516e-05 - val_loss: 2.3790e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3790e-05
#
# Epoch 00044: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 45/10000
# 800/800 [==============================] - 0s 476us/step - loss: 1.0254e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0254e-05 - val_loss: 2.3490e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3490e-05
#
# Epoch 00045: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 46/10000
# 800/800 [==============================] - 0s 417us/step - loss: 1.0262e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0262e-05 - val_loss: 2.3353e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3353e-05
#
# Epoch 00046: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 47/10000
# 800/800 [==============================] - 0s 597us/step - loss: 9.9439e-06 - mean_absolute_error: 0.0024 - mean_squared_error: 9.9439e-06 - val_loss: 2.2744e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.2744e-05
#
# Epoch 00047: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 48/10000
# 800/800 [==============================] - 0s 602us/step - loss: 9.8633e-06 - mean_absolute_error: 0.0024 - mean_squared_error: 9.8633e-06 - val_loss: 2.3101e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.3101e-05
#
# Epoch 00048: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 49/10000
# 800/800 [==============================] - 1s 650us/step - loss: 1.0085e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0085e-05 - val_loss: 2.2666e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.2666e-05
#
# Epoch 00049: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 50/10000
# 800/800 [==============================] - 0s 616us/step - loss: 9.6344e-06 - mean_absolute_error: 0.0024 - mean_squared_error: 9.6344e-06 - val_loss: 2.3345e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.3345e-05
#
# Epoch 00050: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 51/10000
# 800/800 [==============================] - 1s 668us/step - loss: 1.0371e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0371e-05 - val_loss: 2.4156e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4156e-05
#
# Epoch 00051: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 52/10000
# 800/800 [==============================] - 0s 612us/step - loss: 1.0595e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0595e-05 - val_loss: 2.2925e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.2925e-05
#
# Epoch 00052: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 53/10000
# 800/800 [==============================] - 0s 561us/step - loss: 1.0444e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0444e-05 - val_loss: 2.3446e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3446e-05
#
# Epoch 00053: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 54/10000
# 800/800 [==============================] - 0s 539us/step - loss: 1.0555e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0555e-05 - val_loss: 2.3186e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.3186e-05
#
# Epoch 00054: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 55/10000
# 800/800 [==============================] - 0s 500us/step - loss: 1.0580e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0580e-05 - val_loss: 2.3873e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3873e-05
#
# Epoch 00055: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 56/10000
# 800/800 [==============================] - 0s 508us/step - loss: 1.0511e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.0511e-05 - val_loss: 2.3046e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.3046e-05
#
# Epoch 00056: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 57/10000
# 800/800 [==============================] - 0s 473us/step - loss: 1.1661e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1661e-05 - val_loss: 2.4515e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4515e-05
#
# Epoch 00057: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 58/10000
# 800/800 [==============================] - 0s 533us/step - loss: 1.1482e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1482e-05 - val_loss: 2.4012e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.4012e-05
#
# Epoch 00058: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 59/10000
# 800/800 [==============================] - 0s 459us/step - loss: 1.1535e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1535e-05 - val_loss: 2.3231e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 2.3231e-05
#
# Epoch 00059: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 60/10000
# 800/800 [==============================] - 0s 467us/step - loss: 1.1586e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 1.1586e-05 - val_loss: 2.5149e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 2.5149e-05
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00060: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 61/10000
# 800/800 [==============================] - 0s 525us/step - loss: 8.9566e-06 - mean_absolute_error: 0.0023 - mean_squared_error: 8.9566e-06 - val_loss: 2.0471e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 2.0471e-05
#
# Epoch 00061: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 62/10000
# 800/800 [==============================] - 0s 551us/step - loss: 7.3455e-06 - mean_absolute_error: 0.0021 - mean_squared_error: 7.3455e-06 - val_loss: 1.9659e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9659e-05
#
# Epoch 00062: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 63/10000
# 800/800 [==============================] - 0s 549us/step - loss: 6.8989e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.8989e-06 - val_loss: 1.9690e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9690e-05
#
# Epoch 00063: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 64/10000
# 800/800 [==============================] - 0s 542us/step - loss: 6.8267e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.8267e-06 - val_loss: 1.9577e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9577e-05
#
# Epoch 00064: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 65/10000
# 800/800 [==============================] - 0s 592us/step - loss: 6.7939e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.7939e-06 - val_loss: 1.9530e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9530e-05
#
# Epoch 00065: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 66/10000
# 800/800 [==============================] - 0s 547us/step - loss: 6.7960e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.7960e-06 - val_loss: 1.9551e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9551e-05
#
# Epoch 00066: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 67/10000
# 800/800 [==============================] - 0s 576us/step - loss: 6.7117e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.7117e-06 - val_loss: 1.9417e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9417e-05
#
# Epoch 00067: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 68/10000
# 800/800 [==============================] - 0s 546us/step - loss: 6.7117e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.7117e-06 - val_loss: 1.9345e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9345e-05
#
# Epoch 00068: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 69/10000
# 800/800 [==============================] - 0s 537us/step - loss: 6.6128e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6128e-06 - val_loss: 1.9242e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9242e-05
#
# Epoch 00069: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 70/10000
# 800/800 [==============================] - 0s 527us/step - loss: 6.6164e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6164e-06 - val_loss: 1.9168e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9168e-05
#
# Epoch 00070: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 71/10000
# 800/800 [==============================] - 0s 608us/step - loss: 6.6023e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6023e-06 - val_loss: 1.9122e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9122e-05
#
# Epoch 00071: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 72/10000
# 800/800 [==============================] - 0s 555us/step - loss: 6.6396e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6396e-06 - val_loss: 1.9167e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9167e-05
#
# Epoch 00072: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 73/10000
# 800/800 [==============================] - 0s 570us/step - loss: 6.5940e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5940e-06 - val_loss: 1.9212e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9212e-05
#
# Epoch 00073: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 74/10000
# 800/800 [==============================] - 0s 521us/step - loss: 6.6258e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6258e-06 - val_loss: 1.9038e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9038e-05
#
# Epoch 00074: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 75/10000
# 800/800 [==============================] - 0s 586us/step - loss: 6.5039e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5039e-06 - val_loss: 1.9054e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9054e-05
#
# Epoch 00075: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 76/10000
# 800/800 [==============================] - 0s 552us/step - loss: 6.5564e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5564e-06 - val_loss: 1.9044e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9044e-05
#
# Epoch 00076: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 77/10000
# 800/800 [==============================] - 0s 556us/step - loss: 6.6179e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6179e-06 - val_loss: 1.8906e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8906e-05
#
# Epoch 00077: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 78/10000
# 800/800 [==============================] - 0s 532us/step - loss: 6.5259e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5259e-06 - val_loss: 1.8954e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8954e-05
#
# Epoch 00078: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 79/10000
# 800/800 [==============================] - 0s 570us/step - loss: 6.4518e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4518e-06 - val_loss: 1.9187e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9187e-05
#
# Epoch 00079: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 80/10000
# 800/800 [==============================] - 0s 561us/step - loss: 6.6526e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6526e-06 - val_loss: 1.8998e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8998e-05
#
# Epoch 00080: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 81/10000
# 800/800 [==============================] - 0s 598us/step - loss: 6.6150e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6150e-06 - val_loss: 1.8919e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8919e-05
#
# Epoch 00081: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 82/10000
# 800/800 [==============================] - 1s 675us/step - loss: 6.4926e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4926e-06 - val_loss: 1.8761e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8761e-05
#
# Epoch 00082: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 83/10000
# 800/800 [==============================] - 1s 687us/step - loss: 6.5114e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5114e-06 - val_loss: 1.8817e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8817e-05
#
# Epoch 00083: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 84/10000
# 800/800 [==============================] - 1s 813us/step - loss: 6.4128e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4128e-06 - val_loss: 1.8653e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8653e-05
#
# Epoch 00084: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 85/10000
# 800/800 [==============================] - 1s 904us/step - loss: 6.4530e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4530e-06 - val_loss: 1.8599e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8599e-05
#
# Epoch 00085: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 86/10000
# 800/800 [==============================] - 1s 891us/step - loss: 6.3910e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3910e-06 - val_loss: 1.8563e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8563e-05
#
# Epoch 00086: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 87/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3758e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3758e-06 - val_loss: 1.8669e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8669e-05
#
# Epoch 00087: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 88/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4061e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4061e-06 - val_loss: 1.8699e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8699e-05
#
# Epoch 00088: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 89/10000
# 800/800 [==============================] - 1s 981us/step - loss: 6.4010e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4010e-06 - val_loss: 1.8723e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8723e-05
#
# Epoch 00089: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 90/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4139e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4139e-06 - val_loss: 1.8818e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.8818e-05
#
# Epoch 00090: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 91/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4268e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4268e-06 - val_loss: 1.8618e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8618e-05
#
# Epoch 00091: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 92/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3948e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3948e-06 - val_loss: 1.8621e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8621e-05
#
# Epoch 00092: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 93/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4039e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4039e-06 - val_loss: 1.8697e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8697e-05
#
# Epoch 00093: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 94/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4426e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4426e-06 - val_loss: 1.8485e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8485e-05
#
# Epoch 00094: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 95/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5031e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5031e-06 - val_loss: 1.8704e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8704e-05
#
# Epoch 00095: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 96/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4445e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4445e-06 - val_loss: 1.8601e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8601e-05
#
# Epoch 00096: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 97/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3128e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3128e-06 - val_loss: 1.8466e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8466e-05
#
# Epoch 00097: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 98/10000
# 800/800 [==============================] - 1s 2ms/step - loss: 6.2109e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.2109e-06 - val_loss: 1.8156e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8156e-05
#
# Epoch 00098: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 99/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3333e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3333e-06 - val_loss: 1.8303e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8303e-05
#
# Epoch 00099: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 100/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5053e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5053e-06 - val_loss: 1.8575e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8575e-05
#
# Epoch 00100: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 101/10000
# 800/800 [==============================] - 1s 953us/step - loss: 6.4866e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4866e-06 - val_loss: 1.8437e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8437e-05
#
# Epoch 00101: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 102/10000
# 800/800 [==============================] - 1s 954us/step - loss: 6.3532e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3532e-06 - val_loss: 1.8350e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8350e-05
#
# Epoch 00102: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 103/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3796e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3796e-06 - val_loss: 1.8253e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8253e-05
#
# Epoch 00103: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 104/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3643e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3643e-06 - val_loss: 1.8256e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8256e-05
#
# Epoch 00104: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 105/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5095e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5095e-06 - val_loss: 1.8502e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8502e-05
#
# Epoch 00105: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 106/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.2903e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.2903e-06 - val_loss: 1.8495e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8495e-05
#
# Epoch 00106: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 107/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4343e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4343e-06 - val_loss: 1.8165e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8165e-05
#
# Epoch 00107: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 108/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4307e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4307e-06 - val_loss: 1.8366e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8366e-05
#
# Epoch 00108: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 109/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4202e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4202e-06 - val_loss: 1.8322e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8322e-05
#
# Epoch 00109: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 110/10000
# 800/800 [==============================] - ETA: 0s - loss: 6.3894e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.3894e- - 1s 1ms/step - loss: 6.4287e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4287e-06 - val_loss: 1.8289e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8289e-05
#
# Epoch 00110: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 111/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4243e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4243e-06 - val_loss: 1.8225e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8225e-05
#
# Epoch 00111: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 112/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.2805e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.2805e-06 - val_loss: 1.8131e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8131e-05
#
# Epoch 00112: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 113/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3086e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3086e-06 - val_loss: 1.7792e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7792e-05
#
# Epoch 00113: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 114/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.0846e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.0846e-06 - val_loss: 1.8060e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8060e-05
#
# Epoch 00114: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 115/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3619e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3619e-06 - val_loss: 1.7988e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7988e-05
#
# Epoch 00115: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 116/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.2238e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.2238e-06 - val_loss: 1.7872e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7872e-05
#
# Epoch 00116: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 117/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.1917e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.1917e-06 - val_loss: 1.7912e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7912e-05
#
# Epoch 00117: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 118/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.2346e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.2346e-06 - val_loss: 1.7982e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7982e-05
#
# Epoch 00118: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 119/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3562e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3562e-06 - val_loss: 1.8325e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8325e-05
#
# Epoch 00119: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 120/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5124e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5124e-06 - val_loss: 1.7931e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7931e-05
#
# Epoch 00120: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 121/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4106e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4106e-06 - val_loss: 1.7782e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7782e-05
#
# Epoch 00121: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 122/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5522e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5522e-06 - val_loss: 1.8039e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8039e-05
#
# Epoch 00122: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 123/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.3113e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3113e-06 - val_loss: 1.8074e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8074e-05
#
# Epoch 00123: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 124/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.1298e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.1298e-06 - val_loss: 1.7785e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7785e-05
#
# Epoch 00124: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 125/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.0443e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.0443e-06 - val_loss: 1.7794e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7794e-05
#
# Epoch 00125: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 126/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4161e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4161e-06 - val_loss: 1.7897e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7897e-05
#
# Epoch 00126: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 127/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4565e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4565e-06 - val_loss: 1.8318e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8318e-05
#
# Epoch 00127: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 128/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5676e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.5676e-06 - val_loss: 1.7926e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.7926e-05
#
# Epoch 00128: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 129/10000
# 800/800 [==============================] - 1s 2ms/step - loss: 6.3160e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3160e-06 - val_loss: 1.7504e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7504e-05
#
# Epoch 00129: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 130/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.4707e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.4707e-06 - val_loss: 1.8526e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8526e-05
#
# Epoch 00130: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 131/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.6277e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.6277e-06 - val_loss: 1.8088e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8088e-05
#
# Epoch 00131: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 132/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.8631e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.8631e-06 - val_loss: 1.8024e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8024e-05
#
# Epoch 00132: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 133/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 7.7450e-06 - mean_absolute_error: 0.0021 - mean_squared_error: 7.7450e-06 - val_loss: 2.1804e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 2.1804e-05
#
# Epoch 00133: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 134/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 8.9378e-06 - mean_absolute_error: 0.0022 - mean_squared_error: 8.9378e-06 - val_loss: 1.9228e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 1.9228e-05
#
# Epoch 00134: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 135/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 7.4206e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 7.4206e-06 - val_loss: 1.8681e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8681e-05
#
# Epoch 00135: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 136/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 8.7196e-06 - mean_absolute_error: 0.0021 - mean_squared_error: 8.7196e-06 - val_loss: 2.1420e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 2.1420e-05
#
# Epoch 00136: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 137/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0091e-05 - mean_absolute_error: 0.0023 - mean_squared_error: 1.0091e-05 - val_loss: 2.0003e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 2.0003e-05
#
# Epoch 00137: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 138/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 8.7402e-06 - mean_absolute_error: 0.0022 - mean_squared_error: 8.7402e-06 - val_loss: 2.0286e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 2.0286e-05
#
# Epoch 00138: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 139/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 7.4950e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 7.4950e-06 - val_loss: 1.8450e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8450e-05
#
# Epoch 00139: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 140/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.9961e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.9961e-06 - val_loss: 1.8631e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.8631e-05
#
# Epoch 00140: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 141/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.5274e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.5274e-06 - val_loss: 1.7187e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7187e-05
#
# Epoch 00141: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 142/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.0425e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.0425e-06 - val_loss: 1.7644e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7644e-05
#
# Epoch 00142: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 143/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.8722e-06 - mean_absolute_error: 0.0020 - mean_squared_error: 6.8722e-06 - val_loss: 1.7316e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7316e-05
#
# Epoch 00143: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 144/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 6.1928e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.1928e-06 - val_loss: 1.7641e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7641e-05
#
# Epoch 00144: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 145/10000
# 800/800 [==============================] - 1s 829us/step - loss: 6.0927e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.0927e-06 - val_loss: 1.7310e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7310e-05
#
# Epoch 00145: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 146/10000
# 800/800 [==============================] - 1s 884us/step - loss: 6.3570e-06 - mean_absolute_error: 0.0019 - mean_squared_error: 6.3570e-06 - val_loss: 1.7506e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.7506e-05
#
# Epoch 00146: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 147/10000
# ...
#
# Epoch 00890: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 891/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8815e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8815e-06 - val_loss: 1.1269e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1269e-05
#
# Epoch 00891: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 892/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8812e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8812e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00892: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 893/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8812e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8812e-06 - val_loss: 1.1271e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1271e-05
#
# Epoch 00893: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 894/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8811e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8811e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00894: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 895/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8807e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8807e-06 - val_loss: 1.1269e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1269e-05
#
# Epoch 00895: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 896/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8810e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8810e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00896: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 897/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8812e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8812e-06 - val_loss: 1.1271e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1271e-05
#
# Epoch 00897: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 898/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8806e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8806e-06 - val_loss: 1.1267e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1267e-05
#
# Epoch 00898: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 899/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8806e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8806e-06 - val_loss: 1.1270e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1270e-05
#
# Epoch 00899: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 900/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8811e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8811e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00900: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 901/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8802e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8802e-06 - val_loss: 1.1270e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1270e-05
#
# Epoch 00901: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 902/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8803e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8803e-06 - val_loss: 1.1270e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1270e-05
#
# Epoch 00902: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 903/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8806e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8806e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00903: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 904/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8807e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8807e-06 - val_loss: 1.1271e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1271e-05
#
# Epoch 00904: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 905/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8802e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8802e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00905: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 906/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8806e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8806e-06 - val_loss: 1.1269e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1269e-05
#
# Epoch 00906: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 907/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8802e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8802e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00907: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 908/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8803e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8803e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00908: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 909/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8801e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8801e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00909: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 910/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8800e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8800e-06 - val_loss: 1.1267e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1267e-05
#
# Epoch 00910: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 911/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8803e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8803e-06 - val_loss: 1.1270e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1270e-05
#
# Epoch 00911: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 912/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8802e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8802e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00912: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 913/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8801e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8801e-06 - val_loss: 1.1266e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1266e-05
#
# Epoch 00913: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 914/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8800e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8800e-06 - val_loss: 1.1267e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1267e-05
#
# Epoch 00914: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 915/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8797e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8797e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00915: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 916/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8796e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8796e-06 - val_loss: 1.1262e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1262e-05
#
# Epoch 00916: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 917/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8795e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8795e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00917: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 918/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8795e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8795e-06 - val_loss: 1.1266e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1266e-05
#
# Epoch 00918: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 919/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8797e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8797e-06 - val_loss: 1.1267e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1267e-05
#
# Epoch 00919: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 920/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8794e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8794e-06 - val_loss: 1.1270e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1270e-05
#
# Epoch 00920: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 921/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8794e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8794e-06 - val_loss: 1.1264e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1264e-05
#
# Epoch 00921: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 922/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8794e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8794e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00922: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 923/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8793e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8793e-06 - val_loss: 1.1268e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1268e-05
#
# Epoch 00923: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 924/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8788e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8788e-06 - val_loss: 1.1264e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1264e-05
#
# Epoch 00924: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 925/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8788e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8788e-06 - val_loss: 1.1264e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1264e-05
#
# Epoch 00925: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 926/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8793e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8793e-06 - val_loss: 1.1266e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1266e-05
#
# Epoch 00926: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 927/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8785e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8785e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00927: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 928/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8791e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8791e-06 - val_loss: 1.1267e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1267e-05
#
# Epoch 00928: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 929/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8790e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8790e-06 - val_loss: 1.1260e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1260e-05
#
# Epoch 00929: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 930/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8784e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8784e-06 - val_loss: 1.1263e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1263e-05
#
# Epoch 00930: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 931/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8788e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8788e-06 - val_loss: 1.1263e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1263e-05
#
# Epoch 00931: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 932/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8784e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8784e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00932: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 933/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8787e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8787e-06 - val_loss: 1.1264e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1264e-05
#
# Epoch 00933: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 934/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8788e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8788e-06 - val_loss: 1.1263e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1263e-05
#
# Epoch 00934: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 935/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8788e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8788e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00935: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 936/10000
# 800/800 [==============================] - 1s 1ms/step - loss: 1.8783e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8783e-06 - val_loss: 1.1266e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1266e-05
#
# Epoch 00936: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 937/10000
# 800/800 [==============================] - 1s 975us/step - loss: 1.8784e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8784e-06 - val_loss: 1.1265e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1265e-05
#
# Epoch 00937: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 938/10000
# 800/800 [==============================] - 1s 853us/step - loss: 1.8782e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8782e-06 - val_loss: 1.1266e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.1266e-05
#
# Epoch 00938: saving model to ../../../models/model_descriptos_TSmall_sto3g.h5
# Epoch 939/10000
# 736/800 [==========================>...] - ETA: 0s - loss: 1.8678e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8678e-06 ETA: 0s - loss: 1.8609e-06 - mean_absolute_error: 0.0011 - mean_squared_error: 1.8609e-
